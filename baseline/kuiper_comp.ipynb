# %%
import numpy as np
import rubin_sim.maf as maf

# %%
nside=128
slicer = maf.HealpixSlicer(nside=nside)
metric1 = maf.KuiperMetric("rotSkyPos")
metric2 = maf.KuiperMetric("rotTelPos")
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
outDir = 'temp'
resultsDb = maf.db.ResultsDb(outDir=outDir)

# %%
bundleList = []
sql=''
bundleList.append(maf.MetricBundle(metric1, slicer, sql, runName='baseline'))

# %%
bg = maf.metricBundles.MetricBundleGroup(bundleList, 'baseline_v2.1_10yrs.db', outDir=outDir, resultsDb=resultsDb)
bg.runAll()
# Out:
# Querying table None with no constraint for columns ['rotSkyPos', 'fieldRA', 'fieldDec'].
# Found 2081749 visits
# Running:  ['baseline_Kuiper_rotSkyPos_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with "" constraint now.
# 0.0 180.0 -180.0 180.0
# Plotting complete.
